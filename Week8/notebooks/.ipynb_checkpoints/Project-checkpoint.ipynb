# %%
# !pip install faker
# Out:
# Access is denied.

# %%
import sys
# !{sys.executable} -m pip install faker
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting faker
#   Downloading faker-40.28.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: tzdata in c:\programdata\anaconda3\lib\site-packages (from faker) (2025.2)
# Downloading faker-40.28.1-py3-none-any.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------- ----------------------------- 0.5/2.1 MB 3.3 MB/s eta 0:00:01
#    --------------- ------------------------ 0.8/2.1 MB 2.5 MB/s eta 0:00:01
#    ------------------------- -------------- 1.3/2.1 MB 2.2 MB/s eta 0:00:01
#    ------------------------------ --------- 1.6/2.1 MB 2.0 MB/s eta 0:00:01
#    ------------------------------ --------- 1.6/2.1 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 1.5 MB/s eta 0:00:00
# Installing collected packages: faker
# Successfully installed faker-40.28.1
#   WARNING: The script faker.exe is installed in 'C:\Users\singl\AppData\Roaming\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import pandas as pd
from faker import Faker
import random

fake = Faker()

print(fake.name())
print(fake.email())
# Out:
# Ashley Stewart
# fergusonpaul@example.net

# %%
import pandas as pd
from faker import Faker
import random

fake = Faker()

print(fake.name())
print(fake.email())
# Out:
# Nicole Jimenez
# brittanyduran@example.org

# %%
customers = []

for i in range(10):
    customers.append({
        "customer_id": f"C{i+1:03}",
        "customer_name": fake.name(),
        "email": fake.email(),
        "registration_date": fake.date_between(start_date="-2y", end_date="today"),
        "customer_type": random.choice(["REGULAR", "PREMIUM", "VIP"])
    })

customers
# Out:
# [{'customer_id': 'C001',
#   'customer_name': 'Shawn Orozco',
#   'email': 'jessicawilson@example.org',
#   'registration_date': datetime.date(2024, 10, 19),
#   'customer_type': 'VIP'},
#  {'customer_id': 'C002',
#   'customer_name': 'Amy Cowan',
#   'email': 'shermanemily@example.com',
#   'registration_date': datetime.date(2024, 10, 22),
#   'customer_type': 'PREMIUM'},
#  {'customer_id': 'C003',
#   'customer_name': 'Zachary Anderson',
#   'email': 'cody17@example.org',
#   'registration_date': datetime.date(2025, 1, 22),
#   'customer_type': 'REGULAR'},
#  {'customer_id': 'C004',
#   'customer_name': 'Dana Pollard',
#   'email': 'taylorrachel@example.net',
#   'registration_date': datetime.date(2024, 12, 14),
#   'customer_type': 'PREMIUM'},
#  {'customer_id': 'C005',
#   'customer_name': 'Robert Lopez',
#   'email': 'bgreene@example.net',
#   'registration_date': datetime.date(2025, 10, 10),
#   'customer_type': 'VIP'},
#  {'customer_id': 'C006',
#   'customer_name': 'Kyle Brown',
#   'email': 'hturner@example.net',
#   'registration_date': datetime.date(2026, 3, 28),
#   'customer_type': 'PREMIUM'},
#  {'customer_id': 'C007',
#   'customer_name': 'Maria Padilla',
#   'email': 'nathanrosario@example.net',
#   'registration_date': datetime.date(2025, 12, 3),
#   'customer_type': 'PREMIUM'},
#  {'customer_id': 'C008',
#   'customer_name': 'Matthew Cortez',
#   'email': 'shannonwilkinson@example.net',
#   'registration_date': datetime.date(2024, 8, 24),
#   'customer_type': 'VIP'},
#  {'customer_id': 'C009',
#   'customer_name': 'Kristen Wilkins',
#   'email': 'courtney25@example.org',
#   'registration_date': datetime.date(2026, 3, 16),
#   'customer_type': 'REGULAR'},
#  {'customer_id': 'C010',
#   'customer_name': 'Andrew Martin',
#   'email': 'kayla82@example.com',
#   'registration_date': datetime.date(2025, 9, 28),
#   'customer_type': 'PREMIUM'}]

# %%
customers_df = pd.DataFrame(customers)

customers_df
# Out:
#   customer_id     customer_name                         email  \
# 0        C001      Shawn Orozco     jessicawilson@example.org
# 1        C002         Amy Cowan      shermanemily@example.com
# 2        C003  Zachary Anderson            cody17@example.org
# 3        C004      Dana Pollard      taylorrachel@example.net
# 4        C005      Robert Lopez           bgreene@example.net
# 5        C006        Kyle Brown           hturner@example.net
# 6        C007     Maria Padilla     nathanrosario@example.net
# 7        C008    Matthew Cortez  shannonwilkinson@example.net
# 8        C009   Kristen Wilkins        courtney25@example.org
# 9        C010     Andrew Martin           kayla82@example.com
#
#   registration_date customer_type
# 0        2024-10-19           VIP
# 1        2024-10-22       PREMIUM
# 2        2025-01-22       REGULAR
# 3        2024-12-14       PREMIUM
# 4        2025-10-10           VIP
# 5        2026-03-28       PREMIUM
# 6        2025-12-03       PREMIUM
# 7        2024-08-24           VIP
# 8        2026-03-16       REGULAR
# 9        2025-09-28       PREMIUM

# %%
customers_df.to_csv("customers.csv", index=False)

print("customers.csv created successfully!")
# Out:
# customers.csv created successfully!
